# %% [markdown]
# ### 1.	Data Collection and Preprocessing:

# %%
pip install azure-maps-search --pre
# Out:
# Collecting azure-maps-search
#   Downloading azure_maps_search-1.0.0b2-py3-none-any.whl.metadata (18 kB)
# Collecting msrest>=0.6.21 (from azure-maps-search)
#   Downloading msrest-0.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting azure-common~=1.1 (from azure-maps-search)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.3.0 (from azure-maps-search)
#   Downloading azure_mgmt_core-1.4.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting azure-core<2.0.0,>=1.26.2 (from azure-mgmt-core<2.0.0,>=1.3.0->azure-maps-search)
#   Downloading azure_core-1.30.2-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saxen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from msrest>=0.6.21->azure-maps-search) (2024.2.2)
# Collecting isodate>=0.6.0 (from msrest>=0.6.21->azure-maps-search)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.6.21->azure-maps-search)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests~=2.16 in c:\users\saxen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from msrest>=0.6.21->azure-maps-search) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\saxen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from azure-core<2.0.0,>=1.26.2->azure-mgmt-core<2.0.0,>=1.3.0->azure-maps-search) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\saxen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from azure-core<2.0.0,>=1.26.2->azure-mgmt-core<2.0.0,>=1.3.0->azure-maps-search) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saxen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests~=2.16->msrest>=0.6.21->azure-maps-search) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saxen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests~=2.16->msrest>=0.6.21->azure-maps-search) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saxen\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests~=2.16->msrest>=0.6.21->azure-maps-search) (2.2.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-maps-search)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading azure_maps_search-1.0.0b2-py3-none-any.whl (111 kB)
#    ---------------------------------------- 0.0/111.1 kB ? eta -:--:--
#    ---------------------------------------- 111.1/111.1 kB 2.1 MB/s eta 0:00:00
# Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Downloading azure_mgmt_core-1.4.0-py3-none-any.whl (27 kB)
# Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.4 kB ? eta -:--:--
#    ---------------------------------------- 85.4/85.4 kB 5.0 MB/s eta 0:00:00
# Downloading azure_core-1.30.2-py3-none-any.whl (194 kB)
#    ---------------------------------------- 0.0/194.3 kB ? eta -:--:--
#    ---------------------------------------- 194.3/194.3 kB 5.9 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#    ---------------------------------------- 41.7/41.7 kB ? eta 0:00:00
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#    ---------------------------------------- 151.7/151.7 kB ? eta 0:00:00
# Installing collected packages: azure-common, oauthlib, isodate, requests-oauthlib, azure-core, msrest, azure-mgmt-core, azure-maps-search
# Successfully installed azure-common-1.1.28 azure-core-1.30.2 azure-maps-search-1.0.0b2 azure-mgmt-core-1.4.0 isodate-0.6.1 msrest-0.7.1 oauthlib-3.2.2 requests-oauthlib-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import requests
import pandas as pd
from datetime import datetime, timedelta
from azure.core.credentials import AzureKeyCredential
from azure.maps.search import MapsSearchClient
import time

SUBSCRIPTION_KEY = '6Hk0BuzXAh248HIBaBisjFdj0Y7bi97o09bOZMSyakK7IVyu9zSLJQQJ99AGAC8vTInLFAINAAAgAZMP9xmM'  # Replace with your actual subscription key

def search_address(query):
    maps_search_client = MapsSearchClient(credential=AzureKeyCredential(SUBSCRIPTION_KEY))
    result = maps_search_client.search_address(query=query)
    if len(result.results) > 0:
        lat = result.results[0].position.lat
        lon = result.results[0].position.lon
        print(f"Coordinate: {lat}, {lon}")
        return lat, lon
    else:
        print("No address found")
        return None, None

def fetch_historical_weather_data(lat, lon, start_date, end_date):
    params = {
        'api-version': '1.1',
        'query': f"{lat},{lon}",
        'startDate': start_date.strftime('%Y-%m-%d'),
        'endDate': end_date.strftime('%Y-%m-%d'),
        'subscription-key': SUBSCRIPTION_KEY,
    }
    max_retries = 10
    retry_count = 0
    while retry_count < max_retries:
        try:
            response = requests.get("https://atlas.microsoft.com/weather/historical/actuals/daily/json", params=params)
            if response.status_code == 200:
                data = response.json()
                print(f"Fetched data for {start_date.strftime('%Y-%m-%d')} to {end_date.strftime('%Y-%m-%d')}")
                return data
            else:
                print(f"Error fetching data: {response.status_code}, {response.text}")
                retry_count += 1
                if retry_count < max_retries:
                    print(f"Retry attempt {retry_count} in 10 seconds...")
                    time.sleep(10)  # Wait for 10 seconds before retrying
                else:
                    print(f"Failed to fetch data after {max_retries} retries. Skipping this date range.")
                    return None
        except requests.exceptions.ConnectionError as e:
            print(f"ConnectionError: {e}. Retrying...")
            retry_count += 1
            if retry_count < max_retries:
                print(f"Retry attempt {retry_count} in 10 seconds...")
                time.sleep(10)  # Wait for 10 seconds before retrying
            else:
                print(f"Failed to fetch data after {max_retries} retries. Skipping this date range.")
                return None
    
    return None

def preprocess_data(raw_data, location_name):
    processed_data = []
    for day_data in raw_data['results']:
        processed_data.append({
            'location_name': location_name,
            'timestamp': datetime.strptime(day_data['date'], '%Y-%m-%dT%H:%M:%S%z'),  # Convert date string to datetime object
            'temperature_min': day_data['temperature']['minimum']['value'],
            'temperature_max': day_data['temperature']['maximum']['value'],
            'temperature_avg': day_data['temperature']['average']['value'],
            'precipitation': day_data['precipitation']['value'],
            'snowfall': day_data['snowfall']['value'],
            'snow_depth': day_data['snowDepth']['value'],
            'heating_degree_days': day_data['degreeDaySummary']['heating']['value'],
            'cooling_degree_days': day_data['degreeDaySummary']['cooling']['value']
        })
    df = pd.DataFrame(processed_data)
    return df

def file_exists_for_date_range(start_date, end_date):
    file_name_pattern = f'historical_weather_data_{start_date.strftime("%Y%m%d")}_{end_date.strftime("%Y%m%d")}.csv'
    return os.path.exists(file_name_pattern)

if __name__ == "__main__":
    location = "San Francisco, CA"  # Example location
    lat, lon = search_address(location)
    
    if lat and lon:
        end_date = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0) - timedelta(days=1)
        ten_years_ago = datetime.now() - timedelta(days=3652)  # Approximately 10 years ago
        
        start_date = end_date - timedelta(days=30)  # Initial start date 30 days before end_date
        
        while start_date > ten_years_ago:
            if start_date < ten_years_ago + timedelta(days=30):
                start_date = ten_years_ago
            
            if not file_exists_for_date_range(start_date, end_date):
                raw_data = fetch_historical_weather_data(lat, lon, start_date, end_date)
                
                if raw_data:
                    weather_df = preprocess_data(raw_data, location)
                    file_name = f'historical_weather_data_{start_date.strftime("%Y%m%d")}_{end_date.strftime("%Y%m%d")}.csv'
                    weather_df.to_csv(file_name, index=False)
                    print(f"Weather data saved to {file_name}")
                
                end_date = start_date - timedelta(days=1)
                start_date = end_date - timedelta(days=30)
            else:
                print(f"Data for {start_date.strftime('%Y-%m-%d')} to {end_date.strftime('%Y-%m-%d')} already exists. Skipping.")
                end_date = start_date - timedelta(days=1)
                start_date = end_date - timedelta(days=30)
# Out:
# Coordinate: 37.78008, -122.42016
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# Fetched data for 2024-06-06 to 2024-07-06
# Weather data saved to historical_weather_data_20240606_20240706.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2024-05-06 to 2024-06-05
# Weather data saved to historical_weather_data_20240506_20240605.csv
# Fetched data for 2024-04-05 to 2024-05-05
# Weather data saved to historical_weather_data_20240405_20240505.csv
# Fetched data for 2024-03-05 to 2024-04-04
# Weather data saved to historical_weather_data_20240305_20240404.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2024-02-03 to 2024-03-04
# Weather data saved to historical_weather_data_20240203_20240304.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# Fetched data for 2024-01-03 to 2024-02-02
# Weather data saved to historical_weather_data_20240103_20240202.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2023-12-03 to 2024-01-02
# Weather data saved to historical_weather_data_20231203_20240102.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 4 in 10 seconds...
# Fetched data for 2023-11-02 to 2023-12-02
# Weather data saved to historical_weather_data_20231102_20231202.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 4 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 5 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 6 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 7 in 10 seconds...
# Fetched data for 2023-10-02 to 2023-11-01
# Weather data saved to historical_weather_data_20231002_20231101.csv
# Fetched data for 2023-09-01 to 2023-10-01
# Weather data saved to historical_weather_data_20230901_20231001.csv
# Fetched data for 2023-08-01 to 2023-08-31
# Weather data saved to historical_weather_data_20230801_20230831.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# Fetched data for 2023-07-01 to 2023-07-31
# Weather data saved to historical_weather_data_20230701_20230731.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2023-05-31 to 2023-06-30
# Weather data saved to historical_weather_data_20230531_20230630.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2023-04-30 to 2023-05-30
# Weather data saved to historical_weather_data_20230430_20230530.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 4 in 10 seconds...
# Fetched data for 2023-03-30 to 2023-04-29
# Weather data saved to historical_weather_data_20230330_20230429.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2023-02-27 to 2023-03-29
# Weather data saved to historical_weather_data_20230227_20230329.csv
# Fetched data for 2023-01-27 to 2023-02-26
# Weather data saved to historical_weather_data_20230127_20230226.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2022-12-27 to 2023-01-26
# Weather data saved to historical_weather_data_20221227_20230126.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# Fetched data for 2022-11-26 to 2022-12-26
# Weather data saved to historical_weather_data_20221126_20221226.csv
# Fetched data for 2022-10-26 to 2022-11-25
# Weather data saved to historical_weather_data_20221026_20221125.csv
# Fetched data for 2022-09-25 to 2022-10-25
# Weather data saved to historical_weather_data_20220925_20221025.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2022-08-25 to 2022-09-24
# Weather data saved to historical_weather_data_20220825_20220924.csv
# Fetched data for 2022-07-25 to 2022-08-24
# Weather data saved to historical_weather_data_20220725_20220824.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2022-06-24 to 2022-07-24
# Weather data saved to historical_weather_data_20220624_20220724.csv
# Fetched data for 2022-05-24 to 2022-06-23
# Weather data saved to historical_weather_data_20220524_20220623.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2022-04-23 to 2022-05-23
# Weather data saved to historical_weather_data_20220423_20220523.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# Fetched data for 2022-03-23 to 2022-04-22
# Weather data saved to historical_weather_data_20220323_20220422.csv
# Fetched data for 2022-02-20 to 2022-03-22
# Weather data saved to historical_weather_data_20220220_20220322.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2022-01-20 to 2022-02-19
# Weather data saved to historical_weather_data_20220120_20220219.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 4 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 5 in 10 seconds...
# Fetched data for 2021-12-20 to 2022-01-19
# Weather data saved to historical_weather_data_20211220_20220119.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2021-11-19 to 2021-12-19
# Weather data saved to historical_weather_data_20211119_20211219.csv
# Data for 2021-10-19 to 2021-11-18 already exists. Skipping.
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2021-09-18 to 2021-10-18
# Weather data saved to historical_weather_data_20210918_20211018.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 4 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 5 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 6 in 10 seconds...
# Fetched data for 2021-08-18 to 2021-09-17
# Weather data saved to historical_weather_data_20210818_20210917.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# Fetched data for 2021-07-18 to 2021-08-17
# Weather data saved to historical_weather_data_20210718_20210817.csv
# Fetched data for 2021-06-17 to 2021-07-17
# Weather data saved to historical_weather_data_20210617_20210717.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2021-05-17 to 2021-06-16
# Weather data saved to historical_weather_data_20210517_20210616.csv
# Fetched data for 2021-04-16 to 2021-05-16
# Weather data saved to historical_weather_data_20210416_20210516.csv
# Fetched data for 2021-03-16 to 2021-04-15
# Weather data saved to historical_weather_data_20210316_20210415.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2021-02-13 to 2021-03-15
# Weather data saved to historical_weather_data_20210213_20210315.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2021-01-13 to 2021-02-12
# Weather data saved to historical_weather_data_20210113_20210212.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2020-12-13 to 2021-01-12
# Weather data saved to historical_weather_data_20201213_20210112.csv
# Fetched data for 2020-11-12 to 2020-12-12
# Weather data saved to historical_weather_data_20201112_20201212.csv
# Fetched data for 2020-10-12 to 2020-11-11
# Weather data saved to historical_weather_data_20201012_20201111.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# Fetched data for 2020-09-11 to 2020-10-11
# Weather data saved to historical_weather_data_20200911_20201011.csv
# Fetched data for 2020-08-11 to 2020-09-10
# Weather data saved to historical_weather_data_20200811_20200910.csv
# Fetched data for 2020-07-11 to 2020-08-10
# Weather data saved to historical_weather_data_20200711_20200810.csv
# Fetched data for 2020-06-10 to 2020-07-10
# Weather data saved to historical_weather_data_20200610_20200710.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2020-05-10 to 2020-06-09
# Weather data saved to historical_weather_data_20200510_20200609.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2020-04-09 to 2020-05-09
# Weather data saved to historical_weather_data_20200409_20200509.csv
# Fetched data for 2020-03-09 to 2020-04-08
# Weather data saved to historical_weather_data_20200309_20200408.csv
# Fetched data for 2020-02-07 to 2020-03-08
# Weather data saved to historical_weather_data_20200207_20200308.csv
# Fetched data for 2020-01-07 to 2020-02-06
# Weather data saved to historical_weather_data_20200107_20200206.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2019-12-07 to 2020-01-06
# Weather data saved to historical_weather_data_20191207_20200106.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2019-11-06 to 2019-12-06
# Weather data saved to historical_weather_data_20191106_20191206.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 4 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 5 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 6 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 7 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 8 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 9 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Failed to fetch data after 10 retries. Skipping this date range.
# Fetched data for 2019-09-05 to 2019-10-05
# Weather data saved to historical_weather_data_20190905_20191005.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2019-08-05 to 2019-09-04
# Weather data saved to historical_weather_data_20190805_20190904.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2019-07-05 to 2019-08-04
# Weather data saved to historical_weather_data_20190705_20190804.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# Fetched data for 2019-06-04 to 2019-07-04
# Weather data saved to historical_weather_data_20190604_20190704.csv
# Fetched data for 2019-05-04 to 2019-06-03
# Weather data saved to historical_weather_data_20190504_20190603.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2019-04-03 to 2019-05-03
# Weather data saved to historical_weather_data_20190403_20190503.csv
# Fetched data for 2019-03-03 to 2019-04-02
# Weather data saved to historical_weather_data_20190303_20190402.csv
# Fetched data for 2019-01-31 to 2019-03-02
# Weather data saved to historical_weather_data_20190131_20190302.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# Fetched data for 2018-12-31 to 2019-01-30
# Weather data saved to historical_weather_data_20181231_20190130.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# Fetched data for 2018-11-30 to 2018-12-30
# Weather data saved to historical_weather_data_20181130_20181230.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2018-10-30 to 2018-11-29
# Weather data saved to historical_weather_data_20181030_20181129.csv
# Fetched data for 2018-09-29 to 2018-10-29
# Weather data saved to historical_weather_data_20180929_20181029.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 4 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 5 in 10 seconds...
# Fetched data for 2018-08-29 to 2018-09-28
# Weather data saved to historical_weather_data_20180829_20180928.csv
# Fetched data for 2018-07-29 to 2018-08-28
# Weather data saved to historical_weather_data_20180729_20180828.csv
# Fetched data for 2018-06-28 to 2018-07-28
# Weather data saved to historical_weather_data_20180628_20180728.csv
# Fetched data for 2018-05-28 to 2018-06-27
# Weather data saved to historical_weather_data_20180528_20180627.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2018-04-27 to 2018-05-27
# Weather data saved to historical_weather_data_20180427_20180527.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# Fetched data for 2018-03-27 to 2018-04-26
# Weather data saved to historical_weather_data_20180327_20180426.csv
# Fetched data for 2018-02-24 to 2018-03-26
# Weather data saved to historical_weather_data_20180224_20180326.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# Fetched data for 2018-01-24 to 2018-02-23
# Weather data saved to historical_weather_data_20180124_20180223.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2017-12-24 to 2018-01-23
# Weather data saved to historical_weather_data_20171224_20180123.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# Fetched data for 2017-11-23 to 2017-12-23
# Weather data saved to historical_weather_data_20171123_20171223.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 4 in 10 seconds...
# Fetched data for 2017-10-23 to 2017-11-22
# Weather data saved to historical_weather_data_20171023_20171122.csv
# Fetched data for 2017-09-22 to 2017-10-22
# Weather data saved to historical_weather_data_20170922_20171022.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# Fetched data for 2017-08-22 to 2017-09-21
# Weather data saved to historical_weather_data_20170822_20170921.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2017-07-22 to 2017-08-21
# Weather data saved to historical_weather_data_20170722_20170821.csv
# Fetched data for 2017-06-21 to 2017-07-21
# Weather data saved to historical_weather_data_20170621_20170721.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# Fetched data for 2017-05-21 to 2017-06-20
# Weather data saved to historical_weather_data_20170521_20170620.csv
# Fetched data for 2017-04-20 to 2017-05-20
# Weather data saved to historical_weather_data_20170420_20170520.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2017-03-20 to 2017-04-19
# Weather data saved to historical_weather_data_20170320_20170419.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# Fetched data for 2017-02-17 to 2017-03-19
# Weather data saved to historical_weather_data_20170217_20170319.csv
# Fetched data for 2017-01-17 to 2017-02-16
# Weather data saved to historical_weather_data_20170117_20170216.csv
# Fetched data for 2016-12-17 to 2017-01-16
# Weather data saved to historical_weather_data_20161217_20170116.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2016-11-16 to 2016-12-16
# Weather data saved to historical_weather_data_20161116_20161216.csv
# Fetched data for 2016-10-16 to 2016-11-15
# Weather data saved to historical_weather_data_20161016_20161115.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 4 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 5 in 10 seconds...
# Fetched data for 2016-09-15 to 2016-10-15
# Weather data saved to historical_weather_data_20160915_20161015.csv
# Fetched data for 2016-08-15 to 2016-09-14
# Weather data saved to historical_weather_data_20160815_20160914.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 4 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 5 in 10 seconds...
# Fetched data for 2016-07-15 to 2016-08-14
# Weather data saved to historical_weather_data_20160715_20160814.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2016-06-14 to 2016-07-14
# Weather data saved to historical_weather_data_20160614_20160714.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2016-05-14 to 2016-06-13
# Weather data saved to historical_weather_data_20160514_20160613.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# Fetched data for 2016-04-13 to 2016-05-13
# Weather data saved to historical_weather_data_20160413_20160513.csv
# Fetched data for 2016-03-13 to 2016-04-12
# Weather data saved to historical_weather_data_20160313_20160412.csv
# Fetched data for 2016-02-11 to 2016-03-12
# Weather data saved to historical_weather_data_20160211_20160312.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# Fetched data for 2016-01-11 to 2016-02-10
# Weather data saved to historical_weather_data_20160111_20160210.csv
# Fetched data for 2015-12-11 to 2016-01-10
# Weather data saved to historical_weather_data_20151211_20160110.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# Fetched data for 2015-11-10 to 2015-12-10
# Weather data saved to historical_weather_data_20151110_20151210.csv
# Fetched data for 2015-10-10 to 2015-11-09
# Weather data saved to historical_weather_data_20151010_20151109.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2015-09-09 to 2015-10-09
# Weather data saved to historical_weather_data_20150909_20151009.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2015-08-09 to 2015-09-08
# Weather data saved to historical_weather_data_20150809_20150908.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2015-07-09 to 2015-08-08
# Weather data saved to historical_weather_data_20150709_20150808.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2015-06-08 to 2015-07-08
# Weather data saved to historical_weather_data_20150608_20150708.csv
# Fetched data for 2015-05-08 to 2015-06-07
# Weather data saved to historical_weather_data_20150508_20150607.csv
# Fetched data for 2015-04-07 to 2015-05-07
# Weather data saved to historical_weather_data_20150407_20150507.csv
# Fetched data for 2015-03-07 to 2015-04-06
# Weather data saved to historical_weather_data_20150307_20150406.csv
# Fetched data for 2015-02-04 to 2015-03-06
# Weather data saved to historical_weather_data_20150204_20150306.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2015-01-04 to 2015-02-03
# Weather data saved to historical_weather_data_20150104_20150203.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2014-12-04 to 2015-01-03
# Weather data saved to historical_weather_data_20141204_20150103.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2014-11-03 to 2014-12-03
# Weather data saved to historical_weather_data_20141103_20141203.csv
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 1 in 10 seconds...
# Fetched data for 2014-10-03 to 2014-11-02
# Weather data saved to historical_weather_data_20141003_20141102.csv
# Fetched data for 2014-09-02 to 2014-10-02
# Weather data saved to historical_weather_data_20140902_20141002.csv
# Error fetching data: 400, {
#   "error": {
#     "code": "400 BadRequest",
#     "message": "Date range value should be between 1 and 31 inclusive"
#   }
# }
# Retry attempt 1 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 2 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 3 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 4 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 5 in 10 seconds...
# Error fetching data: 400, {
#   "error": {
#     "code": "400 BadRequest",
#     "message": "Date range value should be between 1 and 31 inclusive"
#   }
# }
# Retry attempt 6 in 10 seconds...
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Retrying...
# Retry attempt 7 in 10 seconds...
# Error fetching data: 400, {
#   "error": {
#     "code": "400 BadRequest",
#     "message": "Date range value should be between 1 and 31 inclusive"
#   }
# }
# Retry attempt 8 in 10 seconds...
# Error fetching data: 400, {
#   "error": {
#     "code": "400 BadRequest",
#     "message": "Date range value should be between 1 and 31 inclusive"
#   }
# }
# Retry attempt 9 in 10 seconds...
# Error fetching data: 400, {
#   "error": {
#     "code": "400 BadRequest",
#     "message": "Date range value should be between 1 and 31 inclusive"
#   }
# }
# Failed to fetch data after 10 retries. Skipping this date range.
